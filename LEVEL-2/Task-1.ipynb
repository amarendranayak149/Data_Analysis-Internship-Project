# %% [markdown]
# ### Task 1: Top Cuisines
#
# 1. **Determine the Top Three Most Common Cuisines**
#    Analyze the dataset to identify the three most frequently served cuisines.
#
# 2. **Calculate the Percentage of Restaurants Serving Each of the Top Cuisines**
#    For each of the top cuisines, calculate the proportion of restaurants serving it, expressed as a percentage of the total number of restaurants in the dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url = r"C:\Users\maren\Downloads\COGNIZFY DA Internship\LEVEL-2\Dataset .csv"
# Read the CSV file
df = pd.read_csv(url)
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %% [markdown]
# **Determine the Top Three Most Common Cuisines**
#    Analyze the dataset to identify the three most frequently served cuisines.

# %%
agg_rating_distribution=df['Aggregate rating'].value_counts() 
print(agg_rating_distribution)
# Out:
# Aggregate rating
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: count, dtype: int64

# %%
a=agg_rating_distribution.idxmax()
print("Most common rating range is:", a)
# Out:
# Most common rating range is: 0.0

# %%
plt.hist(df['Aggregate rating'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel("Aggregate rating")
plt.ylabel("Count")
plt.title("Distribution of aggregate rating")
plt.show()

# %% [markdown]
# **Calculate the Percentage of Restaurants Serving Each of the Top Cuisines**
#    For each of the top cuisines, calculate the proportion of restaurants serving it, expressed as a percentage of the total number of restaurants in the dataset.

# %%
avg_vote=round(df['Votes'].mean(),3)
print("The average number of votes received by restaurants: ",avg_vote)
# Out:
# The average number of votes received by restaurants:  156.91
